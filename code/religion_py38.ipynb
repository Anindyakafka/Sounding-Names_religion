# %%
# Universal setup: auto-detects Colab vs local, mounts drive only if needed
import sys, os
sys.path.insert(0, os.path.dirname(os.path.abspath('__file__')) if '__file__' in dir() else os.getcwd())
from config import mount_drive_if_colab

mount_drive_if_colab()
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !apt-get update -y
# !apt-get install python3.8 python3.8-distutils
# !update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1
# !echo 3 | !update-alternatives --config python3
# !apt-get install python3-pip
# !python3 -m pip install --upgrade pip --user
# !export PATH=$PATH:/root/.local/bin

# %%
# %%capture
# Install Python 3.8 dependencies (Colab only — skip if running locally with py38)
import sys, os
sys.path.insert(0, os.path.dirname(os.path.abspath('__file__')) if '__file__' in dir() else os.getcwd())
from config import get_base_dir

base = get_base_dir()
code_dir = os.path.join(base, "code")

# !python3.8 -m ensurepip --upgrade
# !python3.8 -m pip install --upgrade pip
# !python3.8 -m pip install -r {code_dir}/requirements.txt
# !python3.8 -m pip install Unidecode numpy==1.24.4 scikit-learn==1.2.2 pandas==1.3.5

# %%
## Run Prediction

The script `run_py38.py` contains the full religion prediction pipeline with universal path setup.
It is invoked below using Python 3.8 to ensure compatibility with TensorFlow 2.8 / scikit-learn 1.x.
# Out:
# Overwriting run_py38.py

# %%
# Run the religion prediction script with Python 3.8
# !python3.8 run_py38.py
# Out:
# 2
#               name      parent
# 0     Rahul Sharma       Vijay
# 1  Mohammed Zubrai  Ahmed Khan
